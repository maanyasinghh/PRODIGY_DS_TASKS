# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = 'https://raw.githubusercontent.com/datasets/covid-19/master/data/countries-aggregated.csv'
df = pd.read_csv(url)

print(df.isnull().sum())

df = df.dropna()

df = df.rename(columns={'Country/Region': 'Country', 'Confirmed': 'Confirmed_Cases', 'Recovered': 'Recovered_Cases', 'Deaths': 'Deaths'})

print(df.head())
print(df.info())
print(df.describe())

plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Confirmed_Cases')
plt.title('Boxplot of Confirmed Cases')
plt.xlabel('Confirmed Cases')
plt.show()

numeric_columns = ['Confirmed_Cases', 'Recovered_Cases', 'Deaths']
corr_matrix = df[numeric_columns].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# Date         0
# Country      0
# Confirmed    0
# Recovered    0
# Deaths       0
# dtype: int64
#          Date      Country  Confirmed_Cases  Recovered_Cases  Deaths
# 0  2020-01-22  Afghanistan                0                0       0
# 1  2020-01-23  Afghanistan                0                0       0
# 2  2020-01-24  Afghanistan                0                0       0
# 3  2020-01-25  Afghanistan                0                0       0
# 4  2020-01-26  Afghanistan                0                0       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161568 entries, 0 to 161567
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date             161568 non-null  object
#  1   Country          161568 non-null  object
#  2   Confirmed_Cases  161568 non-null  int64
#  3   Recovered_Cases  161568 non-null  int64
#  4   Deaths           161568 non-null  int64
# ...
